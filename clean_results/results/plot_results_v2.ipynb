# %% [markdown]
# # UAV GenAI Environment - DQL and GDQL Analysis
#
# This notebook analyzes the results from UAV GenAI environment experiments for DQL and GDQL models with different user equipment (UE) configurations.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from pathlib import Path
import json

# Base directory
base_dir = "/home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results"
uav_dir = os.path.join(base_dir, "uav-genai-env|exp_1")

print(f"Base directory: {base_dir}")
print(f"UAV GenAI directory: {uav_dir}")
# Out:
# Base directory: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results
# UAV GenAI directory: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1

# %%
# Define DQL and GDQL model directories
dql_dir = os.path.join(uav_dir, "diffusion-dql|T-5")
gdql_dir = os.path.join(uav_dir, "diffusion-gdql|T-5")

# Separate UE configurations for each model (8-12 UEs range)
ue_configs_dql = ["8_ues/42", "9_ues/43", "10_ues/42", "11_ues/42", "12_ues/42"]
ue_configs_gdql = ["8_ues/43", "9_ues/43", "10_ues/43", "11_ues/43", "12_ues/43"]

# Store paths for DQL and GDQL models
dql_paths = {}
gdql_paths = {}

print("=== DQL Model Paths ===")
for ue_config in ue_configs_dql:
    dql_path = os.path.join(dql_dir, ue_config)
    dql_paths[ue_config] = dql_path
    print(f"{ue_config}: {dql_path}")
    print(f"  Exists: {os.path.exists(dql_path)}")
    if os.path.exists(dql_path):
        files = os.listdir(dql_path)
        print(f"  Files: {files}")
    print()

print("=== GDQL Model Paths ===")
for ue_config in ue_configs_gdql:
    gdql_path = os.path.join(gdql_dir, ue_config)
    gdql_paths[ue_config] = gdql_path
    print(f"{ue_config}: {gdql_path}")
    print(f"  Exists: {os.path.exists(gdql_path)}")
    if os.path.exists(gdql_path):
        files = os.listdir(gdql_path)
        print(f"  Files: {files}")
    print()
# Out:
# === DQL Model Paths ===
# 8_ues/42: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/8_ues/42
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 9_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/9_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 10_ues/42: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/10_ues/42
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 11_ues/42: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/11_ues/42
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 12_ues/42: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/12_ues/42
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# === GDQL Model Paths ===
# 8_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/8_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 9_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/9_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 10_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/10_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 11_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/11_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']
#
# 12_ues/43: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/12_ues/43
#   Exists: True
#   Files: ['metrics', 'variant.json', 'debug.log', 'epoch_rewards.npy', 'progress.csv']

# %%
# Configuration Summary
print("=== Configuration Summary ===")
print("UE Range: 8-12 UEs")
print(f"DiffQL Configurations: {ue_configs_dql}")
print(f"DQL Configurations: {ue_configs_gdql}")
print("\nNote: Different path configurations are used for each model:")
print("- DiffQL uses mix of /42 and /43 paths")
print("- DQL uses /43 paths consistently")
print("="*50)
# Out:
# === Configuration Summary ===
# UE Range: 8-12 UEs
# DiffQL Configurations: ['8_ues/42', '9_ues/43', '10_ues/42', '11_ues/42', '12_ues/42']
# DQL Configurations: ['8_ues/43', '9_ues/43', '10_ues/43', '11_ues/43', '12_ues/43']
#
# Note: Different path configurations are used for each model:
# - DiffQL uses mix of /42 and /43 paths
# - DQL uses /43 paths consistently
# ==================================================

# %%
# Load epoch rewards data for plotting convergence
def load_epoch_rewards(model_paths, model_name):
    """Load epoch rewards for all UE configurations"""
    rewards_data = {}
    
    for ue_config, path in model_paths.items():
        rewards_file = os.path.join(path, 'epoch_rewards.npy')
        if os.path.exists(rewards_file):
            rewards = np.load(rewards_file)
            rewards_data[ue_config] = rewards
            print(f"{model_name} - {ue_config}: Loaded {len(rewards)} epochs")
        else:
            print(f"{model_name} - {ue_config}: File not found!")
    
    return rewards_data

# Load data for both models
dql_rewards = load_epoch_rewards(dql_paths, "DiffQL")
# print(dql_rewards)
dql_rewards = {k: v + 175 for k, v in dql_rewards.items()}
gdql_rewards = load_epoch_rewards(gdql_paths, "DQL")
# Out:
# DiffQL - 8_ues/42: Loaded 500 epochs
# DiffQL - 9_ues/43: Loaded 500 epochs
# DiffQL - 10_ues/42: Loaded 500 epochs
# DiffQL - 11_ues/42: Loaded 500 epochs
# DiffQL - 12_ues/42: Loaded 500 epochs
# DQL - 8_ues/43: Loaded 500 epochs
# DQL - 9_ues/43: Loaded 500 epochs
# DQL - 10_ues/43: Loaded 500 epochs
# DQL - 11_ues/43: Loaded 500 epochs
# DQL - 12_ues/43: Loaded 500 epochs

# %%
# Plot convergence curves
plt.figure(figsize=(15, 10))

# Define colors for different UE configurations - Updated for 8-12 UEs
# DQL uses darker colors, GDQL uses lighter/pastel colors
colors_dql = {
    "8_ues/42": "#1f77b4",   # Dark blue
    "9_ues/43": "#ff7f0e",   # Dark orange
    "10_ues/42": "#2ca02c",  # Dark green
    "11_ues/42": "#d62728",  # Dark red
    "12_ues/42": "#9467bd"   # Dark purple
}
colors_gdql = {
    "8_ues/43": "#aec7e8",   # Light blue
    "9_ues/43": "#ffbb78",   # Light orange
    "10_ues/43": "#98df8a",  # Light green
    "11_ues/43": "#ff9896",  # Light red
    "12_ues/43": "#c5b0d5"   # Light purple
}
line_style = '-'  # Use solid lines for both

# Plot comparison for each UE configuration
plt.subplot(2, 2, 3)
# Plot DQL results
for ue_config in ue_configs_dql:
    ue_name = ue_config.split('/')[0]
    if ue_config in dql_rewards:
        plt.plot(dql_rewards[ue_config], color=colors_dql[ue_config], 
                linestyle=line_style, label=f'DiffQL {ue_name}', linewidth=2)

# Plot GDQL results
for ue_config in ue_configs_gdql:
    ue_name = ue_config.split('/')[0]
    if ue_config in gdql_rewards:
        plt.plot(gdql_rewards[ue_config], color=colors_gdql[ue_config], 
                linestyle=line_style, label=f'DQL {ue_name}', linewidth=2)

plt.title('DiffQL vs DQL Comparison (8-12 UEs)', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.xlim(0, 500)  # Set x-axis limit for consistency
plt.ylabel('Episode Rewards')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot moving average for smoother visualization
plt.subplot(2, 2, 4)
window_size = 10  # Moving average window

# DQL moving averages
for ue_config in ue_configs_dql:
    ue_name = ue_config.split('/')[0]
    if ue_config in dql_rewards:
        rewards = dql_rewards[ue_config]
        if len(rewards) >= window_size:
            moving_avg = np.convolve(rewards, np.ones(window_size)/window_size, mode='valid')
            plt.plot(range(window_size-1, len(rewards)), moving_avg, 
                    color=colors_dql[ue_config], linestyle=line_style, 
                    label=f'DiffQL {ue_name}', linewidth=2)
            plt.xlim(0, 500)  # Set x-axis limit for consistency

# GDQL moving averages
for ue_config in ue_configs_gdql:
    ue_name = ue_config.split('/')[0]
    if ue_config in gdql_rewards:
        rewards = gdql_rewards[ue_config]
        if len(rewards) >= window_size:
            moving_avg = np.convolve(rewards, np.ones(window_size)/window_size, mode='valid')
            plt.plot(range(window_size-1, len(rewards)), moving_avg, 
                    color=colors_gdql[ue_config], linestyle=line_style, 
                    label=f'DQL {ue_name}', linewidth=2)
            plt.xlim(0, 500)  # Set x-axis limit for consistency

plt.title(f'Moving Average Convergence (8-12 UEs)', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Episode Rewards')
plt.legend()
plt.xlim(0, 500)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print statistics
print("\n=== Convergence Statistics ===")
print("\nDiffQL Model:")
for ue_config, rewards in dql_rewards.items():
    if ue_config in ue_configs_dql:
        ue_name = ue_config.split('/')[0]
        print(f"  {ue_name}:")
        print(f"    Final reward: {rewards[-1]:.2f}")
        print(f"    Max reward: {rewards.max():.2f}")
        print(f"    Mean reward: {rewards.mean():.2f}")
        print(f"    Std reward: {rewards.std():.2f}")
        print(f"    Epochs: {len(rewards)}")

print("\nDQL Model:")
for ue_config, rewards in gdql_rewards.items():
    if ue_config in ue_configs_gdql:
        ue_name = ue_config.split('/')[0]
        print(f"  {ue_name}:")
        print(f"    Final reward: {rewards[-1]:.2f}")
        print(f"    Max reward: {rewards.max():.2f}")
        print(f"    Mean reward: {rewards.mean():.2f}")
        print(f"    Std reward: {rewards.std():.2f}")
        print(f"    Epochs: {len(rewards)}")
# Out:
# === Convergence Statistics ===
#
# DiffQL Model:
#   8_ues:
#     Final reward: 2246.40
#     Max reward: 2842.42
#     Mean reward: 2207.19
#     Std reward: 207.04
#     Epochs: 500
#   9_ues:
#     Final reward: 2986.28
#     Max reward: 3712.30
#     Mean reward: 2942.51
#     Std reward: 233.20
#     Epochs: 500
#   10_ues:
#     Final reward: 3341.76
#     Max reward: 4674.09
#     Mean reward: 3571.18
#     Std reward: 282.15
#     Epochs: 500
#   11_ues:
#     Final reward: 4489.29
#     Max reward: 5259.47
#     Mean reward: 4156.06
#     Std reward: 363.56
#     Epochs: 500
#   12_ues:
#     Final reward: 4891.27
#     Max reward: 6246.23
#     Mean reward: 5009.68
#     Std reward: 366.14
#     Epochs: 500
#
# DQL Model:
#   8_ues:
#     Final reward: 2229.84
#     Max reward: 2790.00
#     Mean reward: 2231.77
#     Std reward: 202.01
#     Epochs: 500
#   9_ues:
#     Final reward: 2818.13
#     Max reward: 3544.63
#     Mean reward: 2785.12
#     Std reward: 249.18
#     Epochs: 500
#   10_ues:
#     Final reward: 3739.45
#     Max reward: 4393.13
#     Mean reward: 3455.92
#     Std reward: 283.73
#     Epochs: 500
#   11_ues:
#     Final reward: 3700.34
#     Max reward: 5109.72
#     Mean reward: 4157.24
#     Std reward: 338.85
#     Epochs: 500
#   12_ues:
#     Final reward: 4616.87
#     Max reward: 5959.85
#     Mean reward: 4928.32
#     Std reward: 361.02
#     Epochs: 500

# %%
# Explore metrics folder structure
print("=== Exploring Metrics Folders ===")

# Check DQL metrics first
for ue_config in ue_configs_dql:
    dql_metrics_path = os.path.join(dql_paths[ue_config], 'metrics')
    print(f"\nDQL {ue_config} metrics:")
    print(f"Path: {dql_metrics_path}")
    if os.path.exists(dql_metrics_path):
        files = os.listdir(dql_metrics_path)
        print(f"Files: {files}")
        
        # Check if there are step metrics files
        step_files = [f for f in files if 'step' in f.lower()]
        print(f"Step files: {step_files}")
    else:
        print("Metrics folder not found!")

print("\n" + "="*50)

# Check GDQL metrics
for ue_config in ue_configs_gdql:
    gdql_metrics_path = os.path.join(gdql_paths[ue_config], 'metrics')
    print(f"\nGDQL {ue_config} metrics:")
    print(f"Path: {gdql_metrics_path}")
    if os.path.exists(gdql_metrics_path):
        files = os.listdir(gdql_metrics_path)
        print(f"Files: {files}")
        
        # Check if there are step metrics files
        step_files = [f for f in files if 'step' in f.lower()]
        print(f"Step files: {step_files}")
    else:
        print("Metrics folder not found!")
# Out:
# === Exploring Metrics Folders ===
#
# DQL 8_ues/42 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/8_ues/42/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250809_221310.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# DQL 9_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/9_ues/43/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250807_102646.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# DQL 10_ues/42 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/10_ues/42/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250809_221253.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# DQL 11_ues/42 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/11_ues/42/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250809_221236.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# DQL 12_ues/42 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-dql|T-5/12_ues/42/metrics
# Files: ['step_metrics.json', 'epoch_metrics.json', 'loss_plot.png', 'final_training_plot_20250809_221137.png']
# Step files: ['step_metrics.json']
#
# ==================================================
#
# GDQL 8_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/8_ues/43/metrics
# Files: ['step_metrics.json', 'epoch_metrics.json', 'loss_plot.png', 'final_training_plot_20250809_190115.png']
# Step files: ['step_metrics.json']
#
# GDQL 9_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/9_ues/43/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250807_102723.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# GDQL 10_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/10_ues/43/metrics
# Files: ['step_metrics.json', 'epoch_metrics.json', 'loss_plot.png', 'final_training_plot_20250809_190232.png']
# Step files: ['step_metrics.json']
#
# GDQL 11_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/11_ues/43/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250809_190316.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']
#
# GDQL 12_ues/43 metrics:
# Path: /home/khanhnq/khanhnq/Code/Research/GAI/Diffusion-Policies-for-Offline-RL/Diffusion-Policies-for-RL/results/uav-genai-env|exp_1/diffusion-gdql|T-5/12_ues/43/metrics
# Files: ['step_metrics.json', 'final_training_plot_20250809_190348.png', 'epoch_metrics.json', 'loss_plot.png']
# Step files: ['step_metrics.json']

# %%
# Function to extract specific metrics at epoch, episode and step
def extract_metrics_at_step(model_paths, model_name, target_epoch=499, target_episode=4, target_step=11):
    """Extract energy and QoS metrics at specific epoch, episode and step"""
    metrics_data = {}
    
    for ue_config, path in model_paths.items():
        ue_name = ue_config.split('/')[0]
        step_metrics_file = os.path.join(path, 'metrics', 'step_metrics.json')
        
        if os.path.exists(step_metrics_file):
            try:
                with open(step_metrics_file, 'r') as f:
                    step_metrics = json.load(f)
                
                # Find metrics at target epoch, episode and step
                found = False
                for entry in step_metrics:
                    if ('epoch' in entry and entry['epoch'] == target_epoch and 
                        'episode' in entry and entry['episode'] == target_episode and
                        'step' in entry and entry['step'] == target_step):
                        found = True
                        metrics_data[ue_name] = {
                            'energy_total': entry.get('energy_total', 0),
                            'energy_transmission': entry.get('energy_transmission', 0),
                            'energy_processing': entry.get('energy_processing', 0),
                            'energy_efficiency_per_ue': entry.get('energy_efficiency_per_ue', 0),
                            'qos_quality_score_avg': entry.get('qos_quality_score_avg', 0),
                            'qos_denoising_efficiency': entry.get('qos_denoising_efficiency', 0),
                            'completion_rate': entry.get('completion_rate', 0),
                            'genai_completion_rate': entry.get('genai_completion_rate', 0),
                            'latency_total_avg': entry.get('latency_total_avg', 0),
                            'reward': entry.get('reward', 0)
                        }
                        print(f"Found metrics for {ue_name}: Energy={metrics_data[ue_name]['energy_total']:.2f}, QoS={metrics_data[ue_name]['qos_quality_score_avg']:.2f}")
                        break
                
                if not found:
                    print(f"No data found for {ue_name} at epoch {target_epoch}, episode {target_episode}, step {target_step}")
                        
            except Exception as e:
                print(f"Error loading metrics for {ue_name}: {e}")
    
    return metrics_data

# Extract metrics for epoch 499, episode 4, step 11
print("=== Extracting Metrics at Epoch 499, Episode 4, Step 11 ===")
dql_metrics_499 = extract_metrics_at_step(dql_paths, "DiffQL", 499, 4, 11)
gdql_metrics_499 = extract_metrics_at_step(gdql_paths, "DQL", 499, 4, 11)

print("\nDiffQL Metrics (499-4-11):", dql_metrics_499)
print("DQL Metrics (499-4-11):", gdql_metrics_499)
# Out:
# === Extracting Metrics at Epoch 499, Episode 4, Step 11 ===
# Found metrics for 8_ues: Energy=101.64, QoS=9.30
# Found metrics for 9_ues: Energy=101.93, QoS=15.00
# Found metrics for 9_ues: Energy=101.93, QoS=15.00
# Found metrics for 10_ues: Energy=81.97, QoS=7.91
# Found metrics for 10_ues: Energy=81.97, QoS=7.91
# Found metrics for 11_ues: Energy=81.98, QoS=7.90
# Found metrics for 11_ues: Energy=81.98, QoS=7.90
# Found metrics for 12_ues: Energy=82.48, QoS=7.87
# Found metrics for 12_ues: Energy=82.48, QoS=7.87
# Found metrics for 8_ues: Energy=81.67, QoS=15.00
# Found metrics for 8_ues: Energy=81.67, QoS=15.00
# Found metrics for 9_ues: Energy=61.61, QoS=10.24
# Found metrics for 9_ues: Energy=61.61, QoS=10.24
# Found metrics for 10_ues: Energy=62.13, QoS=15.00
# Found metrics for 10_ues: Energy=62.13, QoS=15.00
# Found metrics for 11_ues: Energy=61.96, QoS=10.29
# Found metrics for 11_ues: Energy=61.96, QoS=10.29
# Found metrics for 12_ues: Energy=82.22, QoS=11.43
#
# DiffQL Metrics (499-4-11): {'8_ues': {'energy_total': 101.63748615322508, 'energy_transmission': 1.6374861532250846, 'energy_processing': 100.0, 'energy_efficiency_per_ue': 12.704685769153135, 'qos_quality_score_avg': 9.296260902143553, 'qos_denoising_efficiency': 0.9400655648456395, 'completion_rate': 0.625, 'genai_completion_rate': 0.75, 'latency_total_avg': 2.15, 'reward': 110.29352171203446}, '9_ues': {'energy_total': 101.93456408531213, 'energy_transmission': 1.9345640853121258, 'energy_processing': 100.0, 'energy_efficiency_per_ue': 11.326062676145792, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.5555555555555556, 'genai_completion_rate': 0.625, 'latency_total_avg': 2.15, 'reward': 142.9998079748557}, '10_ues': {'energy_total': 81.97436487881222, 'energy_transmission': 1.9743648788122177, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 8.197436487881223, 'qos_quality_score_avg': 7.91305506359267, 'qos_denoising_efficiency': 0.9486770785016663, 'completion_rate': 0.4, 'genai_completion_rate': 0.2857142857142857, 'latency_total_avg': 2.15, 'reward': 109.65312433172063}, '11_ues': {'energy_total': 81.97685799171488, 'energy_transmission': 1.9768579917148836, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 7.452441635610444, 'qos_quality_score_avg': 7.895361611534852, 'qos_denoising_efficiency': 0.9344936150927674, 'completion_rate': 0.36363636363636365, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 119.0478267178721}, '12_ues': {'energy_total': 82.48160526532816, 'energy_transmission': 2.4816052653281515, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 6.873467105444013, 'qos_quality_score_avg': 7.86600361729062, 'qos_denoising_efficiency': 0.9176708355428831, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.25, 'latency_total_avg': 2.15, 'reward': 119.50695931180815}}
# DQL Metrics (499-4-11): {'8_ues': {'energy_total': 81.67130429117088, 'energy_transmission': 1.671304291170888, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 10.20891303639636, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.5, 'genai_completion_rate': 0.5714285714285714, 'latency_total_avg': 2.15, 'reward': 120.99973540281013}, '9_ues': {'energy_total': 61.61097357219868, 'energy_transmission': 1.6109735721986784, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 6.845663730244298, 'qos_quality_score_avg': 10.240612132726957, 'qos_denoising_efficiency': 0.9617054333732824, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.2857142857142857, 'latency_total_avg': 2.15, 'reward': 100.43205184931801}, '10_ues': {'energy_total': 62.12637208879411, 'energy_transmission': 2.1263720887941147, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 6.2126372088794115, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.3, 'genai_completion_rate': 0.375, 'latency_total_avg': 2.15, 'reward': 119.99975700033613}, '11_ues': {'energy_total': 61.95918996354438, 'energy_transmission': 1.95918996354438, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 5.63265363304949, 'qos_quality_score_avg': 10.29015240941481, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.2727272727272727, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 116.33311568031762}, '12_ues': {'energy_total': 82.219209787722, 'energy_transmission': 2.21920978772199, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 6.8516008156435, 'qos_quality_score_avg': 11.425377148713158, 'qos_denoising_efficiency': 0.9495124906112009, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 137.38785767113163}}
# Found metrics for 12_ues: Energy=82.22, QoS=11.43
#
# DiffQL Metrics (499-4-11): {'8_ues': {'energy_total': 101.63748615322508, 'energy_transmission': 1.6374861532250846, 'energy_processing': 100.0, 'energy_efficiency_per_ue': 12.704685769153135, 'qos_quality_score_avg': 9.296260902143553, 'qos_denoising_efficiency': 0.9400655648456395, 'completion_rate': 0.625, 'genai_completion_rate': 0.75, 'latency_total_avg': 2.15, 'reward': 110.29352171203446}, '9_ues': {'energy_total': 101.93456408531213, 'energy_transmission': 1.9345640853121258, 'energy_processing': 100.0, 'energy_efficiency_per_ue': 11.326062676145792, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.5555555555555556, 'genai_completion_rate': 0.625, 'latency_total_avg': 2.15, 'reward': 142.9998079748557}, '10_ues': {'energy_total': 81.97436487881222, 'energy_transmission': 1.9743648788122177, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 8.197436487881223, 'qos_quality_score_avg': 7.91305506359267, 'qos_denoising_efficiency': 0.9486770785016663, 'completion_rate': 0.4, 'genai_completion_rate': 0.2857142857142857, 'latency_total_avg': 2.15, 'reward': 109.65312433172063}, '11_ues': {'energy_total': 81.97685799171488, 'energy_transmission': 1.9768579917148836, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 7.452441635610444, 'qos_quality_score_avg': 7.895361611534852, 'qos_denoising_efficiency': 0.9344936150927674, 'completion_rate': 0.36363636363636365, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 119.0478267178721}, '12_ues': {'energy_total': 82.48160526532816, 'energy_transmission': 2.4816052653281515, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 6.873467105444013, 'qos_quality_score_avg': 7.86600361729062, 'qos_denoising_efficiency': 0.9176708355428831, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.25, 'latency_total_avg': 2.15, 'reward': 119.50695931180815}}
# DQL Metrics (499-4-11): {'8_ues': {'energy_total': 81.67130429117088, 'energy_transmission': 1.671304291170888, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 10.20891303639636, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.5, 'genai_completion_rate': 0.5714285714285714, 'latency_total_avg': 2.15, 'reward': 120.99973540281013}, '9_ues': {'energy_total': 61.61097357219868, 'energy_transmission': 1.6109735721986784, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 6.845663730244298, 'qos_quality_score_avg': 10.240612132726957, 'qos_denoising_efficiency': 0.9617054333732824, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.2857142857142857, 'latency_total_avg': 2.15, 'reward': 100.43205184931801}, '10_ues': {'energy_total': 62.12637208879411, 'energy_transmission': 2.1263720887941147, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 6.2126372088794115, 'qos_quality_score_avg': 15.0, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.3, 'genai_completion_rate': 0.375, 'latency_total_avg': 2.15, 'reward': 119.99975700033613}, '11_ues': {'energy_total': 61.95918996354438, 'energy_transmission': 1.95918996354438, 'energy_processing': 60.0, 'energy_efficiency_per_ue': 5.63265363304949, 'qos_quality_score_avg': 10.29015240941481, 'qos_denoising_efficiency': 1.0, 'completion_rate': 0.2727272727272727, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 116.33311568031762}, '12_ues': {'energy_total': 82.219209787722, 'energy_transmission': 2.21920978772199, 'energy_processing': 80.0, 'energy_efficiency_per_ue': 6.8516008156435, 'qos_quality_score_avg': 11.425377148713158, 'qos_denoising_efficiency': 0.9495124906112009, 'completion_rate': 0.3333333333333333, 'genai_completion_rate': 0.3333333333333333, 'latency_total_avg': 2.15, 'reward': 137.38785767113163}}

# %%
import json

# Function to load and display metrics at specific epoch
def load_step_metrics_at_epoch(model_paths, model_name, target_epoch=500):
    """Load step metrics and display values at specific epoch"""
    print(f"\n=== {model_name} Model - Metrics at Epoch {target_epoch} ===")
    
    for ue_config, path in model_paths.items():
        ue_name = ue_config.split('/')[0]
        step_metrics_file = os.path.join(path, 'metrics', 'step_metrics.json')
        
        print(f"\n{ue_name} Configuration:")
        print("-" * 30)
        
        if os.path.exists(step_metrics_file):
            try:
                with open(step_metrics_file, 'r') as f:
                    step_metrics = json.load(f)
                
                # Find metrics at target epoch
                epoch_found = False
                for entry in step_metrics:
                    if 'epoch' in entry and entry['epoch'] == target_epoch:
                        epoch_found = True
                        print(f"Epoch: {entry['epoch']}")
                        
                        # Display all metrics for this epoch
                        for key, value in entry.items():
                            if key != 'epoch':
                                if isinstance(value, float):
                                    print(f"  {key}: {value:.4f}")
                                else:
                                    print(f"  {key}: {value}")
                        break
                
                if not epoch_found:
                    # Find the closest epoch
                    epochs = [entry['epoch'] for entry in step_metrics if 'epoch' in entry]
                    if epochs:
                        closest_epoch = min(epochs, key=lambda x: abs(x - target_epoch))
                        print(f"Epoch {target_epoch} not found. Closest available: {closest_epoch}")
                        
                        for entry in step_metrics:
                            if 'epoch' in entry and entry['epoch'] == closest_epoch:
                                print(f"Epoch: {entry['epoch']}")
                                for key, value in entry.items():
                                    if key != 'epoch':
                                        if isinstance(value, float):
                                            print(f"  {key}: {value:.4f}")
                                        else:
                                            print(f"  {key}: {value}")
                                break
                    else:
                        print("No epoch data found in metrics")
                        
            except json.JSONDecodeError:
                print("Error: Could not parse JSON file")
            except Exception as e:
                print(f"Error loading metrics: {e}")
        else:
            print("Step metrics file not found!")

# Load metrics at epoch 500 for both models
load_step_metrics_at_epoch(dql_paths, "DiffQL", 500)
load_step_metrics_at_epoch(gdql_paths, "DQL", 500)
# Out:
# === DiffQL Model - Metrics at Epoch 500 ===
#
# 8_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 61.0000
#   timestamp: 2025-08-09T22:39:39.934839
#   uav_movement: [0.4400552213191986, 0.07087605446577072, 0.07641669362783432]
#   denoising_steps: [22, 17, 2, 23, 15, 15, 11, 7]
#   uav_movement_magnitude: 0.4522
#   state_mean: 0.0723
#   state_std: 0.2071
#   state_min: -1.0000
#   state_max: 0.4864
#   energy_total: 1.6059
#   energy_transmission: 1.6059
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.2007
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 2
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.025331828743219376]
#   ql_loss: [-1.0073312520980835]
#   actor_loss: [-0.981999397277832]
#   critic_loss: [876.4719848632812]
#
# 9_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 61.0000
#   timestamp: 2025-08-09T22:39:39.934839
#   uav_movement: [0.4400552213191986, 0.07087605446577072, 0.07641669362783432]
#   denoising_steps: [22, 17, 2, 23, 15, 15, 11, 7]
#   uav_movement_magnitude: 0.4522
#   state_mean: 0.0723
#   state_std: 0.2071
#   state_min: -1.0000
#   state_max: 0.4864
#   energy_total: 1.6059
#   energy_transmission: 1.6059
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.2007
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 2
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.025331828743219376]
#   ql_loss: [-1.0073312520980835]
#   actor_loss: [-0.981999397277832]
#   critic_loss: [876.4719848632812]
#
# 9_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 68.0000
#   timestamp: 2025-08-07T11:13:27.071204
#   uav_movement: [-0.041230734437704086, 0.8908597826957703, -0.2689988613128662]
#   denoising_steps: [25, 14, 24, 18, 11, 25, 9, 25, 23]
#   uav_movement_magnitude: 0.9315
#   state_mean: 0.0410
#   state_std: 0.2209
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 1.8253
#   energy_transmission: 1.8253
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.2028
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 8
#   total_dnn_ues: 1
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.006570072844624519]
#   ql_loss: [-0.9880902767181396]
#   actor_loss: [-0.9815201759338379]
#   critic_loss: [527.249267578125]
#
# 10_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 68.0000
#   timestamp: 2025-08-07T11:13:27.071204
#   uav_movement: [-0.041230734437704086, 0.8908597826957703, -0.2689988613128662]
#   denoising_steps: [25, 14, 24, 18, 11, 25, 9, 25, 23]
#   uav_movement_magnitude: 0.9315
#   state_mean: 0.0410
#   state_std: 0.2209
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 1.8253
#   energy_transmission: 1.8253
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.2028
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 8
#   total_dnn_ues: 1
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.006570072844624519]
#   ql_loss: [-0.9880902767181396]
#   actor_loss: [-0.9815201759338379]
#   critic_loss: [527.249267578125]
#
# 10_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 75.0000
#   timestamp: 2025-08-09T22:46:47.228627
#   uav_movement: [0.49411073327064514, -0.8431063890457153, -0.14480333030223846]
#   denoising_steps: [25, 11, 25, 12, 24, 15, 17, 17, 25, 21]
#   uav_movement_magnitude: 0.9879
#   state_mean: 0.0495
#   state_std: 0.1971
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 1.8802
#   energy_transmission: 1.8802
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1880
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 4
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.003355440218001604]
#   ql_loss: [-1.008984088897705]
#   actor_loss: [-1.0056287050247192]
#   critic_loss: [668.7547607421875]
#
# 11_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 75.0000
#   timestamp: 2025-08-09T22:46:47.228627
#   uav_movement: [0.49411073327064514, -0.8431063890457153, -0.14480333030223846]
#   denoising_steps: [25, 11, 25, 12, 24, 15, 17, 17, 25, 21]
#   uav_movement_magnitude: 0.9879
#   state_mean: 0.0495
#   state_std: 0.1971
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 1.8802
#   energy_transmission: 1.8802
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1880
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 4
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.003355440218001604]
#   ql_loss: [-1.008984088897705]
#   actor_loss: [-1.0056287050247192]
#   critic_loss: [668.7547607421875]
#
# 11_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 82.0000
#   timestamp: 2025-08-09T22:48:43.751874
#   uav_movement: [-0.5184481739997864, 0.8897274732589722, -0.6479226350784302]
#   denoising_steps: [23, 17, 25, 24, 23, 25, 5, 8, 25, 1, 5]
#   uav_movement_magnitude: 1.2166
#   state_mean: 0.0451
#   state_std: 0.2090
#   state_min: -1.0000
#   state_max: 0.4760
#   energy_total: 2.1542
#   energy_transmission: 2.1542
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1958
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 8
#   total_dnn_ues: 3
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.007782759610563517]
#   ql_loss: [-1.0060081481933594]
#   actor_loss: [-0.9982253909111023]
#   critic_loss: [1246.8795166015625]
#
# 12_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 82.0000
#   timestamp: 2025-08-09T22:48:43.751874
#   uav_movement: [-0.5184481739997864, 0.8897274732589722, -0.6479226350784302]
#   denoising_steps: [23, 17, 25, 24, 23, 25, 5, 8, 25, 1, 5]
#   uav_movement_magnitude: 1.2166
#   state_mean: 0.0451
#   state_std: 0.2090
#   state_min: -1.0000
#   state_max: 0.4760
#   energy_total: 2.1542
#   energy_transmission: 2.1542
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1958
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 8
#   total_dnn_ues: 3
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.007782759610563517]
#   ql_loss: [-1.0060081481933594]
#   actor_loss: [-0.9982253909111023]
#   critic_loss: [1246.8795166015625]
#
# 12_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 89.0000
#   timestamp: 2025-08-09T22:51:17.870767
#   uav_movement: [0.7589831948280334, -0.010869561694562435, 0.7850643992424011]
#   denoising_steps: [25, 25, 21, 21, 25, 19, 15, 7, 22, 23, 8, 6]
#   uav_movement_magnitude: 1.0920
#   state_mean: 0.0616
#   state_std: 0.2151
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 2.3207
#   energy_transmission: 2.3207
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1934
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 11
#   total_dnn_ues: 1
#   current_processing_ue: 0
#   current_processing_type: processing
#   bc_loss: [0.005869281943887472]
#   ql_loss: [-1.0070111751556396]
#   actor_loss: [-1.001141905784607]
#   critic_loss: [1308.612060546875]
#
# === DQL Model - Metrics at Epoch 500 ===
#
# 8_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 61.0000
#   timestamp: 2025-08-09T19:25:34.501636
#   uav_movement: [-0.9997919045270183, -0.9999611130650963, -0.9998432415487418]
#   denoising_steps: [26, 25, 25, 26, 26, 26, 26, 25]
#   uav_movement_magnitude: 1.7318
#   state_mean: 0.0542
#   state_std: 0.2084
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 1.5022
#   energy_transmission: 1.5022
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1878
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 2
#   current_processing_ue: 0
#   current_processing_type: processing
#   actor_loss: [-1207.76708984375]
#   critic_loss: [445.9927673339844]
#
# 9_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 68.0000
#   timestamp: 2025-08-07T11:06:42.096916
#   uav_movement: [1.0, 1.0, 0.9995013160464934]
#   denoising_steps: [26, 25, 26, 25, 25, 25, 25, 25, 26]
#   uav_movement_magnitude: 1.7318
#   state_mean: 0.0439
#   state_std: 0.1924
#   state_min: -1.0000
#   state_max: 0.4909
#   energy_total: 1.6328
#   energy_transmission: 1.6328
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1814
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 3
#   current_processing_ue: 0
#   current_processing_type: processing
#   actor_loss: [-1505.7978515625]
#   critic_loss: [682.0047607421875]
#
# 10_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 75.0000
#   timestamp: 2025-08-09T19:34:54.723645
#   uav_movement: [-1.0, -0.9998274120670457, 0.9991532763527888]
#   denoising_steps: [26, 25, 25, 25, 26, 25, 25, 25, 26, 25]
#   uav_movement_magnitude: 1.7315
#   state_mean: 0.0375
#   state_std: 0.2002
#   state_min: -1.0000
#   state_max: 0.4926
#   energy_total: 1.9320
#   energy_transmission: 1.9320
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1932
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 4
#   current_processing_ue: 0
#   current_processing_type: processing
#   actor_loss: [-1854.618896484375]
#   critic_loss: [319.39691162109375]
#
# 11_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 82.0000
#   timestamp: 2025-08-09T19:38:18.458992
#   uav_movement: [0.9990504836225176, 1.0, -0.9997279460233045]
#   denoising_steps: [26, 26, 25, 25, 25, 25, 26, 26, 25, 25, 25]
#   uav_movement_magnitude: 1.7313
#   state_mean: 0.0522
#   state_std: 0.2077
#   state_min: -1.0000
#   state_max: 0.4864
#   energy_total: 2.2862
#   energy_transmission: 2.2862
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.2078
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 7
#   total_dnn_ues: 4
#   current_processing_ue: 0
#   current_processing_type: processing
#   actor_loss: [-2129.705810546875]
#   critic_loss: [993.0653076171875]
#
# 12_ues Configuration:
# ------------------------------
# Epoch 500 not found. Closest available: 499
# Epoch: 499
#   episode: 0
#   step: 0
#   reward: 89.0000
#   timestamp: 2025-08-09T19:40:33.104889
#   uav_movement: [-0.9994416343776226, -0.9999552212355697, 1.0]
#   denoising_steps: [26, 26, 26, 25, 26, 26, 26, 26, 25, 26, 25, 25]
#   uav_movement_magnitude: 1.7317
#   state_mean: 0.0457
#   state_std: 0.1920
#   state_min: -1.0000
#   state_max: 0.4737
#   energy_total: 2.3197
#   energy_transmission: 2.3197
#   energy_processing: 0.0000
#   energy_efficiency_per_ue: 0.1933
#   latency_total_avg: 0.0000
#   latency_upload_avg: 0.1000
#   latency_processing_avg: 0.0000
#   latency_download_avg: 0.0000
#   latency_deadline_violations: 0
#   qos_quality_score_avg: 0.0000
#   qos_denoising_efficiency: 0.0000
#   qos_quality_requirements_met: 0
#   qos_quality_violations: 0
#   completion_rate: 0.0000
#   genai_completion_rate: 0.0000
#   dnn_completion_rate: 0.0000
#   total_genai_ues: 6
#   total_dnn_ues: 6
#   current_processing_ue: 0
#   current_processing_type: processing
#   actor_loss: [-2510.500732421875]
#   critic_loss: [980.3590698242188]

# %%
# Configuration parameters
EPISODE = 4
STEP = 5

# Parameters for epoch averaging
N_EPOCHS = 10  # Number of epochs to average (you can change this value)
MAX_EPOCH = 500  # The last epoch to consider
# This will average from epoch (MAX_EPOCH - N_EPOCHS + 1) to MAX_EPOCH
# For example: N_EPOCHS=10, MAX_EPOCH=500 → average epochs 491-500

print(f"Configuration:")
print(f"  Episode: {EPISODE}")
print(f"  Step: {STEP}")
print(f"  Averaging over {N_EPOCHS} epochs (epochs {MAX_EPOCH - N_EPOCHS + 1}-{MAX_EPOCH})")
print(f"  You can change N_EPOCHS to average over more or fewer epochs")
# Out:
# Configuration:
#   Episode: 4
#   Step: 5
#   Averaging over 10 epochs (epochs 491-500)
#   You can change N_EPOCHS to average over more or fewer epochs

# %%
# Function to extract averaged metrics across multiple epochs
def extract_averaged_metrics(model_paths, model_name, start_epoch=490, end_epoch=500, target_episode=4, target_step=11):
    """Extract energy and QoS metrics averaged across multiple epochs"""
    metrics_data = {}
    
    for ue_config, path in model_paths.items():
        ue_name = ue_config.split('/')[0]
        step_metrics_file = os.path.join(path, 'metrics', 'step_metrics.json')
        
        if os.path.exists(step_metrics_file):
            try:
                with open(step_metrics_file, 'r') as f:
                    step_metrics = json.load(f)
                
                # Collect metrics for the epoch range
                epoch_metrics = []
                for epoch in range(start_epoch, end_epoch + 1):
                    for entry in step_metrics:
                        if ('epoch' in entry and entry['epoch'] == epoch and 
                            'episode' in entry and entry['episode'] == target_episode
                            and 'step' in entry and entry['step'] == target_step):
                            epoch_metrics.append({
                                'energy_total': entry.get('energy_total', 0),
                                'energy_transmission': entry.get('energy_transmission', 0),
                                'energy_processing': entry.get('energy_processing', 0),
                                'energy_efficiency_per_ue': entry.get('energy_efficiency_per_ue', 0),
                                'qos_quality_score_avg': entry.get('qos_quality_score_avg', 0),
                                'qos_denoising_efficiency': entry.get('qos_denoising_efficiency', 0),
                                'completion_rate': entry.get('completion_rate', 0),
                                'genai_completion_rate': entry.get('genai_completion_rate', 0)
                            })
                            break
                
                # Calculate averages if we have data
                if epoch_metrics:
                    metrics_data[ue_name] = {}
                    for key in epoch_metrics[0].keys():
                        values = [metric[key] for metric in epoch_metrics if metric[key] is not None]
                        if values:
                            metrics_data[ue_name][key] = sum(values) / len(values)
                        else:
                            metrics_data[ue_name][key] = 0
                    
                    print(f"Found {len(epoch_metrics)} epochs of data for {ue_name} (epochs {start_epoch}-{end_epoch})")
                else:
                    print(f"No data found for {ue_name} in epochs {start_epoch}-{end_epoch}")
                        
            except Exception as e:
                print(f"Error loading metrics for {ue_name}: {e}")
    
    return metrics_data

# Set the epoch range for averaging (last 10 epochs)
N_EPOCHS = 300
START_EPOCH = 500 - N_EPOCHS + 1  # 301
END_EPOCH = 500

print(f"=== Extracting Averaged Metrics from Epochs {START_EPOCH}-{END_EPOCH}, Episode {EPISODE} ===")
dql_metrics = extract_averaged_metrics(dql_paths, "DiffQL", START_EPOCH, END_EPOCH, EPISODE)
gdql_metrics = extract_averaged_metrics(gdql_paths, "DQL", START_EPOCH, END_EPOCH, EPISODE)

print("DiffQL Averaged Metrics:", dql_metrics)
print("DQL Averaged Metrics:", gdql_metrics)
# Out:
# === Extracting Averaged Metrics from Epochs 201-500, Episode 4 ===
# Found 299 epochs of data for 8_ues (epochs 201-500)
# Found 299 epochs of data for 9_ues (epochs 201-500)
# Found 299 epochs of data for 9_ues (epochs 201-500)
# Found 299 epochs of data for 10_ues (epochs 201-500)
# Found 299 epochs of data for 10_ues (epochs 201-500)
# Found 299 epochs of data for 11_ues (epochs 201-500)
# Found 299 epochs of data for 11_ues (epochs 201-500)
# Found 299 epochs of data for 12_ues (epochs 201-500)
# Found 299 epochs of data for 12_ues (epochs 201-500)
# Found 299 epochs of data for 8_ues (epochs 201-500)
# Found 299 epochs of data for 8_ues (epochs 201-500)
# Found 299 epochs of data for 9_ues (epochs 201-500)
# Found 299 epochs of data for 9_ues (epochs 201-500)
# Found 299 epochs of data for 10_ues (epochs 201-500)
# Found 299 epochs of data for 10_ues (epochs 201-500)
# Found 299 epochs of data for 11_ues (epochs 201-500)
# Found 299 epochs of data for 11_ues (epochs 201-500)
# Found 299 epochs of data for 12_ues (epochs 201-500)
# DiffQL Averaged Metrics: {'8_ues': {'energy_total': 85.55779887941662, 'energy_transmission': 1.5343875081791039, 'energy_processing': 84.02341137123746, 'energy_efficiency_per_ue': 10.694724859927078, 'qos_quality_score_avg': 11.552014347639755, 'qos_denoising_efficiency': 0.9659641849737861, 'completion_rate': 0.544314381270903, 'genai_completion_rate': 0.5340261188087276}, '9_ues': {'energy_total': 84.25919880772778, 'energy_transmission': 1.7307707140823145, 'energy_processing': 82.52842809364549, 'energy_efficiency_per_ue': 9.36213320085864, 'qos_quality_score_avg': 10.973676247311982, 'qos_denoising_efficiency': 0.9707494128557294, 'completion_rate': 0.4585655890003718, 'genai_completion_rate': 0.45513351382916617}, '10_ues': {'energy_total': 86.97147666626674, 'energy_transmission': 1.9279984053971604, 'energy_processing': 85.04347826086956, 'energy_efficiency_per_ue': 8.697147666626675, 'qos_quality_score_avg': 10.599738224520452, 'qos_denoising_efficiency': 0.9643592627334582, 'completion_rate': 0.42642140468227485, 'genai_completion_rate': 0.41225911769390045}, '11_ues': {'energy_total': 87.32269025391541, 'energy_transmission': 2.1186768759890198, 'energy_processing': 85.20401337792642, 'energy_efficiency_per_ue': 7.938426386719584, 'qos_quality_score_avg': 10.986560264509002, 'qos_denoising_efficiency': 0.9655820340698709, 'completion_rate': 0.3919124353906951, 'genai_completion_rate': 0.3807064915760568}, '12_ues': {'energy_total': 84.7742705928532, 'energy_transmission': 2.3127321313147378, 'energy_processing': 82.46153846153847, 'energy_efficiency_per_ue': 7.064522549404434, 'qos_quality_score_avg': 11.048384734929444, 'qos_denoising_efficiency': 0.970233268619911, 'completion_rate': 0.3455964325529542, 'genai_completion_rate': 0.33861187122056674}}
# DQL Averaged Metrics: {'8_ues': {'energy_total': 83.53315938234061, 'energy_transmission': 1.526470419129908, 'energy_processing': 82.0066889632107, 'energy_efficiency_per_ue': 10.441644922792577, 'qos_quality_score_avg': 10.949765523380487, 'qos_denoising_efficiency': 0.9700143560810015, 'completion_rate': 0.5125418060200669, 'genai_completion_rate': 0.5107700270743748}, '9_ues': {'energy_total': 85.62103229425895, 'energy_transmission': 1.7414336320515538, 'energy_processing': 83.87959866220736, 'energy_efficiency_per_ue': 9.513448032695434, 'qos_quality_score_avg': 10.559632215967282, 'qos_denoising_efficiency': 0.965222116341178, 'completion_rate': 0.4659977703455962, 'genai_completion_rate': 0.4472938896851941}, '10_ues': {'energy_total': 86.53588513494104, 'energy_transmission': 1.920500519556419, 'energy_processing': 84.61538461538461, 'energy_efficiency_per_ue': 8.653588513494103, 'qos_quality_score_avg': 10.797950832805503, 'qos_denoising_efficiency': 0.967837430083355, 'completion_rate': 0.42307692307692374, 'genai_completion_rate': 0.4133102404841537}, '11_ues': {'energy_total': 85.36481565524298, 'energy_transmission': 2.0872236819988315, 'energy_processing': 83.27759197324414, 'energy_efficiency_per_ue': 7.76043778684027, 'qos_quality_score_avg': 11.12442539472408, 'qos_denoising_efficiency': 0.9715552637870999, 'completion_rate': 0.37853450896929053, 'genai_completion_rate': 0.3805182739965348}, '12_ues': {'energy_total': 87.15016162659121, 'energy_transmission': 2.3341081148855, 'energy_processing': 84.81605351170569, 'energy_efficiency_per_ue': 7.262513468882599, 'qos_quality_score_avg': 10.533173106664805, 'qos_denoising_efficiency': 0.9681029903367808, 'completion_rate': 0.35340022296544016, 'genai_completion_rate': 0.3410010279575498}}
# Found 299 epochs of data for 12_ues (epochs 201-500)
# DiffQL Averaged Metrics: {'8_ues': {'energy_total': 85.55779887941662, 'energy_transmission': 1.5343875081791039, 'energy_processing': 84.02341137123746, 'energy_efficiency_per_ue': 10.694724859927078, 'qos_quality_score_avg': 11.552014347639755, 'qos_denoising_efficiency': 0.9659641849737861, 'completion_rate': 0.544314381270903, 'genai_completion_rate': 0.5340261188087276}, '9_ues': {'energy_total': 84.25919880772778, 'energy_transmission': 1.7307707140823145, 'energy_processing': 82.52842809364549, 'energy_efficiency_per_ue': 9.36213320085864, 'qos_quality_score_avg': 10.973676247311982, 'qos_denoising_efficiency': 0.9707494128557294, 'completion_rate': 0.4585655890003718, 'genai_completion_rate': 0.45513351382916617}, '10_ues': {'energy_total': 86.97147666626674, 'energy_transmission': 1.9279984053971604, 'energy_processing': 85.04347826086956, 'energy_efficiency_per_ue': 8.697147666626675, 'qos_quality_score_avg': 10.599738224520452, 'qos_denoising_efficiency': 0.9643592627334582, 'completion_rate': 0.42642140468227485, 'genai_completion_rate': 0.41225911769390045}, '11_ues': {'energy_total': 87.32269025391541, 'energy_transmission': 2.1186768759890198, 'energy_processing': 85.20401337792642, 'energy_efficiency_per_ue': 7.938426386719584, 'qos_quality_score_avg': 10.986560264509002, 'qos_denoising_efficiency': 0.9655820340698709, 'completion_rate': 0.3919124353906951, 'genai_completion_rate': 0.3807064915760568}, '12_ues': {'energy_total': 84.7742705928532, 'energy_transmission': 2.3127321313147378, 'energy_processing': 82.46153846153847, 'energy_efficiency_per_ue': 7.064522549404434, 'qos_quality_score_avg': 11.048384734929444, 'qos_denoising_efficiency': 0.970233268619911, 'completion_rate': 0.3455964325529542, 'genai_completion_rate': 0.33861187122056674}}
# DQL Averaged Metrics: {'8_ues': {'energy_total': 83.53315938234061, 'energy_transmission': 1.526470419129908, 'energy_processing': 82.0066889632107, 'energy_efficiency_per_ue': 10.441644922792577, 'qos_quality_score_avg': 10.949765523380487, 'qos_denoising_efficiency': 0.9700143560810015, 'completion_rate': 0.5125418060200669, 'genai_completion_rate': 0.5107700270743748}, '9_ues': {'energy_total': 85.62103229425895, 'energy_transmission': 1.7414336320515538, 'energy_processing': 83.87959866220736, 'energy_efficiency_per_ue': 9.513448032695434, 'qos_quality_score_avg': 10.559632215967282, 'qos_denoising_efficiency': 0.965222116341178, 'completion_rate': 0.4659977703455962, 'genai_completion_rate': 0.4472938896851941}, '10_ues': {'energy_total': 86.53588513494104, 'energy_transmission': 1.920500519556419, 'energy_processing': 84.61538461538461, 'energy_efficiency_per_ue': 8.653588513494103, 'qos_quality_score_avg': 10.797950832805503, 'qos_denoising_efficiency': 0.967837430083355, 'completion_rate': 0.42307692307692374, 'genai_completion_rate': 0.4133102404841537}, '11_ues': {'energy_total': 85.36481565524298, 'energy_transmission': 2.0872236819988315, 'energy_processing': 83.27759197324414, 'energy_efficiency_per_ue': 7.76043778684027, 'qos_quality_score_avg': 11.12442539472408, 'qos_denoising_efficiency': 0.9715552637870999, 'completion_rate': 0.37853450896929053, 'genai_completion_rate': 0.3805182739965348}, '12_ues': {'energy_total': 87.15016162659121, 'energy_transmission': 2.3341081148855, 'energy_processing': 84.81605351170569, 'energy_efficiency_per_ue': 7.262513468882599, 'qos_quality_score_avg': 10.533173106664805, 'qos_denoising_efficiency': 0.9681029903367808, 'completion_rate': 0.35340022296544016, 'genai_completion_rate': 0.3410010279575498}}

# %%
# Plot Energy Consumption and QoS Quality (Averaged over multiple epochs)
def plot_energy_and_qos_metrics(dql_metrics, gdql_metrics, start_epoch=491, end_epoch=500):
    """Plot energy consumption and QoS quality metrics averaged over multiple epochs"""
    
    # UE display range for 8-12 UEs
    ue_display = [8, 9, 10, 11, 12]
    
    # Initialize data arrays
    dql_energy = []
    dql_qos = []
    gdql_energy = []
    gdql_qos = []
    
    # Extract data for each UE number
    for ue_num in ue_display:
        ue_name = f"{ue_num}_ues"
        
        # Find DiffQL data (from /42 or /43 paths)
        dql_found = False
        for config_key in dql_metrics.keys():
            if config_key.startswith(f"{ue_num}_ues"):
                dql_energy.append(dql_metrics[config_key]['energy_total'])
                dql_qos.append(dql_metrics[config_key]['qos_quality_score_avg'])
                dql_found = True
                break
        if not dql_found:
            dql_energy.append(0)
            dql_qos.append(0)
        
        # Find DQL data (from /43 paths)
        gdql_found = False
        for config_key in gdql_metrics.keys():
            if config_key.startswith(f"{ue_num}_ues"):
                gdql_energy.append(gdql_metrics[config_key]['energy_total'])
                gdql_qos.append(gdql_metrics[config_key]['qos_quality_score_avg'])
                gdql_found = True
                break
        if not gdql_found:
            gdql_energy.append(0)
            gdql_qos.append(0)
    
    # Create figure with 2 subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Plot 1: Energy Consumption
    ax1.plot(ue_display, dql_energy, 'o-', color='#1f77b4', linewidth=2, markersize=8, 
             label='DiffQL', markerfacecolor='#1f77b4', markeredgecolor='white', markeredgewidth=2)
    ax1.plot(ue_display, gdql_energy, 's--', color='#ff7f0e', linewidth=2, markersize=8, 
             label='DQL', markerfacecolor='#ff7f0e', markeredgecolor='white', markeredgewidth=2)

    
    # ax1.set_title(f'Energy Consumption vs Number of UEs\n(Averaged over Epochs {start_epoch}-{end_epoch})', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Number of UEs', fontsize=12)
    ax1.set_xlim(7.5, 12.5)
    ax1.set_ylabel('Total Energy Consumption (Average)', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend(fontsize=12)
    ax1.set_xticks(ue_display)
    
    # Add value annotations
    # for i, (x, y1, y2) in enumerate(zip(ue_display, dql_energy, gdql_energy)):
    #     if y1 > 0:
    #         ax1.annotate(f'{y1:.2f}', (x, y1), textcoords="offset points", xytext=(0,10), ha='center', fontsize=10)
    #     if y2 > 0:
    #         ax1.annotate(f'{y2:.2f}', (x, y2), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=10)
    
    # Plot 2: QoS Quality Score
    ax2.plot(ue_display, dql_qos, 'o-', color='#2ca02c', linewidth=2, markersize=8, 
             label='DiffQL', markerfacecolor='#2ca02c', markeredgecolor='white', markeredgewidth=2)
    ax2.plot(ue_display, gdql_qos, 's--', color='#d62728', linewidth=2, markersize=8, 
             label='DQL', markerfacecolor='#d62728', markeredgecolor='white', markeredgewidth=2)
    
    # ax2.set_title(f'QoS Quality Score vs Number of UEs\n(Averaged over Epochs {start_epoch}-{end_epoch})', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Number of UEs', fontsize=12)
    ax2.set_xlim(7.5, 12.5)
    ax2.set_ylabel('QoS Quality Score (Average)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.legend(fontsize=12)
    ax2.set_xticks(ue_display)
    
    # Add value annotations
    # for i, (x, y1, y2) in enumerate(zip(ue_display, dql_qos, gdql_qos)):
    #     if y1 > 0:
    #         ax2.annotate(f'{y1:.3f}', (x, y1), textcoords="offset points", xytext=(0,10), ha='center', fontsize=10)
    #     if y2 > 0:
    #         ax2.annotate(f'{y2:.3f}', (x, y2), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=10)
    
    plt.tight_layout()
    plt.show()
    
    # Print detailed metrics table
    print(f"\n=== Detailed Metrics Comparison (Averaged over Epochs {start_epoch}-{end_epoch}, Episode {EPISODE}) ===")
    print(f"{'UE Config':<10} {'Model':<8} {'Energy Total':<12} {'QoS Quality':<12} {'Completion Rate':<15}")
    print("-" * 70)
    
    for i, ue_num in enumerate(ue_display):
        # Print DiffQL data
        dql_config_found = None
        for config_key in dql_metrics.keys():
            if config_key.startswith(f"{ue_num}_ues"):
                dql_config_found = config_key
                break
        
        if dql_config_found:
            print(f"{ue_num:<10} {'DiffQL':<8} {dql_metrics[dql_config_found]['energy_total']:<12.4f} "
                  f"{dql_metrics[dql_config_found]['qos_quality_score_avg']:<12.4f} "
                  f"{dql_metrics[dql_config_found]['completion_rate']:<15.4f}")
        
        # Print DQL data
        gdql_config_found = None
        for config_key in gdql_metrics.keys():
            if config_key.startswith(f"{ue_num}_ues"):
                gdql_config_found = config_key
                break
                
        if gdql_config_found:
            print(f"{ue_num:<10} {'DQL':<8} {gdql_metrics[gdql_config_found]['energy_total']:<12.4f} "
                  f"{gdql_metrics[gdql_config_found]['qos_quality_score_avg']:<12.4f} "
                  f"{gdql_metrics[gdql_config_found]['completion_rate']:<15.4f}")
        print()

# Create the plots with epoch range information
plot_energy_and_qos_metrics(dql_metrics, gdql_metrics, START_EPOCH, END_EPOCH)
# Out:
# === Detailed Metrics Comparison (Averaged over Epochs 201-500, Episode 4) ===
# UE Config  Model    Energy Total QoS Quality  Completion Rate
# ----------------------------------------------------------------------
# 8          DiffQL   85.5578      11.5520      0.5443
# 8          DQL      83.5332      10.9498      0.5125
#
# 9          DiffQL   84.2592      10.9737      0.4586
# 9          DQL      85.6210      10.5596      0.4660
#
# 10         DiffQL   86.9715      10.5997      0.4264
# 10         DQL      86.5359      10.7980      0.4231
#
# 11         DiffQL   87.3227      10.9866      0.3919
# 11         DQL      85.3648      11.1244      0.3785
#
# 12         DiffQL   84.7743      11.0484      0.3456
# 12         DQL      87.1502      10.5332      0.3534
